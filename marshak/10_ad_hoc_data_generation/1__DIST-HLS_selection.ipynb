# %%
import geopandas as gpd

from pystac_client import Client  
from pystac_client import ItemSearch
from pystac.item import Item
from shapely.geometry import box, shape
import yaml
from rasterio.crs import CRS
import datetime
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import rasterio
from rasterio.merge import merge
import numpy as np
import asf_search as asf
from dem_stitcher.rio_tools import reproject_arr_to_new_crs, reproject_arr_to_match_profile
import shutil
import numpy as np
import matplotlib.pyplot as plt

# %%
yaml_file = 'events/papau_new_guinea_2024.yml' #'porto_algre.yml'
with open(yaml_file) as f:
    event_dict = yaml.safe_load(f)["event"]
event_dict
# Out:
# {'event_name': 'papau_new_guinea_2024',
#  'bounds': [143.3, -5.4, 143.4, -5.3],
#  'event_date': '2024-05-24',
#  'pre_event_window_days': 100,
#  'post_event_window_days': 60,
#  'rtc_track_numbers': [9, 133],
#  'mgrs_tiles': ['54MYV'],
#  'dist_hls_confirmed_change_min_days': 15,
#  'links': ['https://www.cnn.com/2024/05/28/asia/papua-new-guinea-landslide-satellite-imagery-intl/index.html']}

# %%
EVENT_DT = datetime.datetime.strptime(event_dict['event_date'], "%Y-%m-%d")
PRE_DT_START = EVENT_DT - datetime.timedelta(days=event_dict['pre_event_window_days'])
POST_DT_STOP = EVENT_DT + datetime.timedelta(days=event_dict['post_event_window_days'])

# %%
event_dict['bounds']
# Out:
# [143.3, -5.4, 143.4, -5.3]

# %%
aoi = box(*event_dict['bounds'])
df_aoi = gpd.GeoDataFrame(geometry=[aoi], crs=CRS.from_epsg(4326))

# %%
#df_mgrs = gpd.read_file('https://raw.githubusercontent.com/NASA-IMPACT/hls-land_tiles/master/s2_grid.json')

# %%
stac = 'https://cmr.earthdata.nasa.gov/cloudstac/'    # CMR-STAC API Endpoint
api = Client.open(f'{stac}/LPCLOUD/')
collections = ['OPERA_L3_DIST-ALERT-HLS_V1']

search_params = {"collections": collections,
                 "intersects": aoi.__geo_interface__,
                 "datetime": [EVENT_DT - datetime.timedelta(days=14), POST_DT_STOP],
                 "max_items": 1000}
search_dswx = api.search(**search_params)

# %%
l = list(search_dswx.items())
len(l)
# Out:
# 40

# %%
def format_item(item):
    assets_status = [(key, value.href) for (key, value) in sorted(item.assets.items()) if ('STATUS' in value.href and '.tif' in value.href)]
    assets_status_m = [('dist-veg-status', value) if 'VEG' in key else ('dist-gen-status', value) for (key, value) in assets_status]

    assets_date = [(key, value.href) for (key, value) in sorted(item.assets.items()) if ('DATE' in value.href and '.tif' in value.href and 'LAST' not in value.href)]
    assets_date_m = [('dist-veg-date', value) if 'VEG' in key else ('dist-gen-date', value) for (key, value) in assets_date]
    
    out = {**{'id': item.id}, 
           **item.properties, 
           **{'geometry': shape(item.geometry)},
           **{key: value for (key, value) in assets_status_m + assets_date_m}
          }
    return out

# %%
data = list(map(format_item, l))
df_resp = pd.DataFrame(data)
df_resp = gpd.GeoDataFrame(df_resp, geometry=df_resp.geometry, crs=CRS.from_epsg(4326))
df_resp['datetime'] = pd.to_datetime(df_resp['datetime'])
df_resp['acq_date']= df_resp['datetime'].dt.date
df_resp['sensor'] = df_resp['id'].map(lambda oid: oid.split('_')[-3]) 
df_resp.head()
# Out:
#                                                   id  eo:cloud_cover  \
# 0  OPERA_L3_DIST-ALERT-HLS_T54MYV_20240510T003732...             100
# 1  OPERA_L3_DIST-ALERT-HLS_T54MYV_20240511T005709...              99
# 2  OPERA_L3_DIST-ALERT-HLS_T54MYV_20240513T004711...              55
# 3  OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639...              91
# 4  OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639...              91
#
#                           datetime            start_datetime  \
# 0 2024-05-10 00:37:32.603000+00:00  2024-05-10T00:37:32.603Z
# 1 2024-05-11 00:58:24.409000+00:00  2024-05-11T00:58:24.409Z
# 2 2024-05-13 00:48:31.699000+00:00  2024-05-13T00:48:31.699Z
# 3 2024-05-18 00:36:39.749000+00:00  2024-05-18T00:36:39.749Z
# 4 2024-05-18 00:36:39.749000+00:00  2024-05-18T00:36:39.749Z
#
#                end_datetime  \
# 0  2024-05-10T00:37:32.603Z
# 1  2024-05-11T00:58:24.409Z
# 2  2024-05-13T00:48:31.699Z
# 3  2024-05-18T00:36:39.749Z
# 4  2024-05-18T00:36:39.749Z
#
#                                             geometry  \
# 0  POLYGON ((142.80499 -5.51396, 143.67509 -5.510...
# 1  POLYGON ((142.80499 -5.51396, 143.38584 -5.511...
# 2  POLYGON ((143.19640 -5.51265, 143.79547 -5.510...
# 3  POLYGON ((143.70942 -5.38366, 143.79323 -5.007...
# 4  POLYGON ((143.70942 -5.38366, 143.79323 -5.007...
#
#                                      dist-gen-status  \
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
#
#                                      dist-veg-status  \
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
#
#                                        dist-gen-date  \
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
#
#                                        dist-veg-date    acq_date sensor
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  2024-05-10     L9
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  2024-05-11    S2B
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  2024-05-13    S2A
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  2024-05-18     L8
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  2024-05-18     L8

# %%
fig, ax = plt.subplots()
df_resp.exterior.plot(ax = ax)
df_aoi.plot(ax=ax)
# Out:
# <Axes: >

# %%
df_resp.acq_date.unique()
# Out:
# array([datetime.date(2024, 5, 10), datetime.date(2024, 5, 11),
#        datetime.date(2024, 5, 13), datetime.date(2024, 5, 18),
#        datetime.date(2024, 5, 23), datetime.date(2024, 5, 26),
#        datetime.date(2024, 5, 28), datetime.date(2024, 5, 31),
#        datetime.date(2024, 6, 2), datetime.date(2024, 6, 3),
#        datetime.date(2024, 6, 5), datetime.date(2024, 6, 7),
#        datetime.date(2024, 6, 10), datetime.date(2024, 6, 11),
#        datetime.date(2024, 6, 12), datetime.date(2024, 6, 15),
#        datetime.date(2024, 6, 17), datetime.date(2024, 6, 19),
#        datetime.date(2024, 6, 20), datetime.date(2024, 6, 22),
#        datetime.date(2024, 6, 25), datetime.date(2024, 6, 27),
#        datetime.date(2024, 6, 30), datetime.date(2024, 7, 2),
#        datetime.date(2024, 7, 5), datetime.date(2024, 7, 7),
#        datetime.date(2024, 7, 10), datetime.date(2024, 7, 12),
#        datetime.date(2024, 7, 13), datetime.date(2024, 7, 15),
#        datetime.date(2024, 7, 17), datetime.date(2024, 7, 20),
#        datetime.date(2024, 7, 22)], dtype=object)

# %%
dist_hls = Path('out') / event_dict['event_name'] / 'dist_hls'
dist_hls.mkdir(exist_ok=True, parents=True)

# %%
# %%time

for (sensor, date), df_rtc_date in tqdm(df_resp.groupby(['sensor', 'acq_date']), desc='dates'):
    dist_veg = df_rtc_date['dist-veg-status']
    dist_gen = df_rtc_date['dist-gen-status']

    dist_veg_date = df_rtc_date['dist-veg-date']
    dist_gen_date = df_rtc_date['dist-gen-date']
    
    date_dir = dist_hls / f'{str(date)}__{sensor}'
    date_dir.mkdir(exist_ok=True, parents=True)

    asf.download_urls(urls=dist_veg, path=date_dir, processes=5)
    asf.download_urls(urls=dist_gen, path=date_dir, processes=5)
    asf.download_urls(urls=dist_veg_date, path=date_dir, processes=5)
    asf.download_urls(urls=dist_gen_date, path=date_dir, processes=5)
# Out:
# dates:   0%|                                            | 0/37 [00:00<?, ?it/s]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T154238Z_L8_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T213539Z_L8_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T213539Z_L8_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T154238Z_L8_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T154238Z_L8_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T213539Z_L8_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T213539Z_L8_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T003639Z_20240522T154238Z_L8_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:   3%|▉                                   | 1/37 [00:01<00:47,  1.31s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240603T003636Z_20240605T141711Z_L8_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240603T003636Z_20240605T141711Z_L8_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240603T003636Z_20240605T141711Z_L8_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240603T003636Z_20240605T141711Z_L8_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:   5%|█▉                                  | 2/37 [00:02<00:45,  1.30s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240619T003644Z_20240621T061057Z_L8_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240619T003644Z_20240621T061057Z_L8_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240619T003644Z_20240621T061057Z_L8_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240619T003644Z_20240621T061057Z_L8_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:   8%|██▉                                 | 3/37 [00:03<00:43,  1.27s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T003652Z_20240708T072044Z_L8_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T003652Z_20240708T072044Z_L8_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T003652Z_20240708T072044Z_L8_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T003652Z_20240708T072044Z_L8_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  11%|███▉                                | 4/37 [00:05<00:41,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240510T003732Z_20240514T134023Z_L9_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240510T003732Z_20240514T134023Z_L9_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240510T003732Z_20240514T134023Z_L9_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240510T003732Z_20240514T134023Z_L9_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  14%|████▊                               | 5/37 [00:06<00:39,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T003656Z_20240528T132647Z_L9_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T003656Z_20240528T132647Z_L9_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T003656Z_20240528T132647Z_L9_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T003656Z_20240528T132647Z_L9_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  16%|█████▊                              | 6/37 [00:07<00:38,  1.24s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240611T003650Z_20240623T105512Z_L9_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240611T003650Z_20240623T105512Z_L9_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240611T003650Z_20240623T105512Z_L9_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240611T003650Z_20240623T105512Z_L9_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  19%|██████▊                             | 7/37 [00:08<00:37,  1.26s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T003635Z_20240629T070148Z_L9_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T003635Z_20240629T070148Z_L9_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T003635Z_20240629T070148Z_L9_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T003635Z_20240629T070148Z_L9_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  22%|███████▊                            | 8/37 [00:10<00:36,  1.27s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240713T003657Z_20240715T052148Z_L9_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240713T003657Z_20240715T052148Z_L9_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240713T003657Z_20240715T052148Z_L9_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240713T003657Z_20240715T052148Z_L9_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  24%|████████▊                           | 9/37 [00:11<00:35,  1.26s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240513T004711Z_20240515T194754Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240513T004711Z_20240515T194754Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240513T004711Z_20240515T194754Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240513T004711Z_20240515T194754Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  27%|█████████▍                         | 10/37 [00:12<00:33,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240523T004701Z_20240525T144115Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240523T004701Z_20240525T144115Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240523T004701Z_20240525T144115Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240523T004701Z_20240525T144115Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  30%|██████████▍                        | 11/37 [00:13<00:32,  1.26s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T005711Z_20240528T132710Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T005711Z_20240528T132710Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T005711Z_20240528T132710Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240526T005711Z_20240528T132710Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  32%|███████████▎                       | 12/37 [00:15<00:31,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240602T004711Z_20240604T233305Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240602T004711Z_20240604T233305Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240602T004711Z_20240604T233305Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240602T004711Z_20240604T233305Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  35%|████████████▎                      | 13/37 [00:16<00:29,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T024847Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T062129Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T062129Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T024847Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T062129Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T024847Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T024847Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240605T005711Z_20240611T062129Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  38%|█████████████▏                     | 14/37 [00:17<00:29,  1.26s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T062441Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T025054Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T062441Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T025054Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T062441Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T025054Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T025054Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240612T004711Z_20240614T062441Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  41%|██████████████▏                    | 15/37 [00:19<00:28,  1.30s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240615T005711Z_20240617T052903Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240615T005711Z_20240617T052903Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240615T005711Z_20240617T052903Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240615T005711Z_20240617T052903Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  43%|███████████████▏                   | 16/37 [00:20<00:26,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240622T004711Z_20240624T081536Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240622T004711Z_20240624T081536Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240622T004711Z_20240624T081536Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240622T004711Z_20240624T081536Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  46%|████████████████                   | 17/37 [00:21<00:25,  1.27s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240625T005711Z_20240627T103449Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240625T005711Z_20240627T103449Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240625T005711Z_20240627T103449Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240625T005711Z_20240627T103449Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  49%|█████████████████                  | 18/37 [00:22<00:24,  1.27s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240702T004711Z_20240707T120058Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240702T004711Z_20240707T120058Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240702T004711Z_20240707T120058Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240702T004711Z_20240707T120058Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  51%|█████████████████▉                 | 19/37 [00:24<00:22,  1.26s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T005711Z_20240708T072110Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T005711Z_20240708T072110Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T005711Z_20240708T072110Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240705T005711Z_20240708T072110Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  54%|██████████████████▉                | 20/37 [00:25<00:21,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240712T004711Z_20240714T095909Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240712T004711Z_20240714T095909Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240712T004711Z_20240714T095909Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240712T004711Z_20240714T095909Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  57%|███████████████████▊               | 21/37 [00:26<00:20,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240715T005711Z_20240717T095755Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240715T005711Z_20240717T095755Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240715T005711Z_20240717T095755Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240715T005711Z_20240717T095755Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  59%|████████████████████▊              | 22/37 [00:27<00:18,  1.25s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240722T004711Z_20240724T061856Z_S2A_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240722T004711Z_20240724T061856Z_S2A_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240722T004711Z_20240724T061856Z_S2A_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240722T004711Z_20240724T061856Z_S2A_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  62%|█████████████████████▊             | 23/37 [00:29<00:17,  1.27s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240511T005709Z_20240513T110958Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240511T005709Z_20240513T110958Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240511T005709Z_20240513T110958Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240511T005709Z_20240513T110958Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  65%|██████████████████████▋            | 24/37 [00:30<00:16,  1.29s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T004659Z_20240520T160701Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T004659Z_20240520T160701Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T004659Z_20240520T160701Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240518T004659Z_20240520T160701Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  68%|███████████████████████▋           | 25/37 [00:31<00:15,  1.30s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240528T004709Z_20240530T114341Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240528T004709Z_20240530T114341Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240528T004709Z_20240530T114341Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240528T004709Z_20240530T114341Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# ...
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240607T004709Z_20240612T104432Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240607T004709Z_20240612T104432Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  76%|██████████████████████████▍        | 28/37 [00:35<00:11,  1.32s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240610T005709Z_20240612T054145Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240610T005709Z_20240612T054145Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240610T005709Z_20240612T054145Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240610T005709Z_20240612T054145Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  78%|███████████████████████████▍       | 29/37 [00:36<00:10,  1.31s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240617T004709Z_20240619T062616Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240617T004709Z_20240619T062616Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240617T004709Z_20240619T062616Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240617T004709Z_20240619T062616Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  81%|████████████████████████████▍      | 30/37 [00:38<00:09,  1.30s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240620T005709Z_20240622T083256Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240620T005709Z_20240622T083256Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240620T005709Z_20240622T083256Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240620T005709Z_20240622T083256Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  84%|█████████████████████████████▎     | 31/37 [00:39<00:07,  1.29s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T004709Z_20240629T070211Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T004709Z_20240629T070211Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T004709Z_20240629T070211Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240627T004709Z_20240629T070211Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  86%|██████████████████████████████▎    | 32/37 [00:40<00:06,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240630T005709Z_20240702T201612Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240630T005709Z_20240702T201612Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240630T005709Z_20240702T201612Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240630T005709Z_20240702T201612Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  89%|███████████████████████████████▏   | 33/37 [00:42<00:05,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240707T004709Z_20240709T041511Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240707T004709Z_20240709T041511Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240707T004709Z_20240709T041511Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240707T004709Z_20240709T041511Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  92%|████████████████████████████████▏  | 34/37 [00:43<00:03,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240710T005709Z_20240712T095836Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240710T005709Z_20240712T095836Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240710T005709Z_20240712T095836Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240710T005709Z_20240712T095836Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  95%|█████████████████████████████████  | 35/37 [00:44<00:02,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240717T004709Z_20240719T121500Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240717T004709Z_20240719T121500Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240717T004709Z_20240719T121500Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240717T004709Z_20240719T121500Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates:  97%|██████████████████████████████████ | 36/37 [00:45<00:01,  1.28s/it]/Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240720T005709Z_20240723T101226Z_S2B_30_v1_VEG-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240720T005709Z_20240723T101226Z_S2B_30_v1_GEN-DIST-STATUS.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240720T005709Z_20240723T101226Z_S2B_30_v1_VEG-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /Users/cmarshak/miniforge3/envs/dist-s1/lib/python3.12/site-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/OPERA_L3_DIST-ALERT-HLS_T54MYV_20240720T005709Z_20240723T101226Z_S2B_30_v1_GEN-DIST-DATE.tif
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# dates: 100%|███████████████████████████████████| 37/37 [00:47<00:00,  1.28s/it]
# CPU times: user 485 ms, sys: 2.09 s, total: 2.57 s
# Wall time: 47.2 s

# %% [markdown]
# # Merge

# %%
all_acq_dirs = sorted([acq_dir for acq_dir in dist_hls.glob('*')])
all_acq_dirs = list(filter(lambda p: p.is_dir(), all_acq_dirs))
all_acq_dirs
# Out:
# [PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-10__L9'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__L8'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__L9'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-31__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-03__L8'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-11__L9'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-19__L8'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__L9'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__L8'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-13__L9'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A'),
#  PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-25__S2A')]

# %%
import concurrent.futures
import warnings
from typing import Union

import numpy as np
import rasterio
from rasterio.crs import CRS
from rasterio.enums import Resampling
from rasterio.io import MemoryFile
from rasterio.merge import merge
from rasterio.windows import Window
from shapely.geometry import box
from tqdm import tqdm

def merge_arrays_with_geometadata(
    arrays: list[np.ndarray],
    profiles: list[dict],
    resampling='bilinear',
    nodata = None,
    dtype: str = None,
    method='first',
) -> tuple[np.ndarray, dict]:
    n_dim = arrays[0].shape
    if len(n_dim) not in [2, 3]:
        raise ValueError('Currently arrays must be in BIP format' 'i.e. channels x height x width or flat array')
    if len(set([len(arr.shape) for arr in arrays])) != 1:
        raise ValueError('All arrays must have same number of dimensions i.e. 2 or 3')

    if len(n_dim) == 2:
        arrays_input = [arr[np.newaxis, ...] for arr in arrays]
    else:
        arrays_input = arrays

    if (len(arrays)) != (len(profiles)):
        raise ValueError('Length of arrays and profiles needs to be the same')

    memfiles = [MemoryFile() for p in profiles]
    datasets = [mfile.open(**p) for (mfile, p) in zip(memfiles, profiles)]
    [ds.write(arr) for (ds, arr) in zip(datasets, arrays_input)]

    if dtype is None:
        dst_dtype = profiles[0]['dtype']
    if nodata is None:
        dst_nodata = profiles[0]['nodata']

    merged_arr, merged_trans = merge(
        datasets, resampling=Resampling[resampling], method=method, nodata=dst_nodata, dtype=dst_dtype
    )

    prof_merged = profiles[0].copy()
    prof_merged['transform'] = merged_trans
    prof_merged['count'] = merged_arr.shape[0]
    prof_merged['height'] = merged_arr.shape[1]
    prof_merged['width'] = merged_arr.shape[2]
    prof_merged['nodata'] = dst_nodata
    prof_merged['dtype'] = dst_dtype
    
    [ds.close() for ds in datasets]
    [mfile.close() for mfile in memfiles]

    return merged_arr, prof_merged

# %%
#from dem_stitcher.merge import merge_arrays_with_geometadata

def get_crs(path: str) -> Path:
    with rasterio.open(path) as ds:
        crs = ds.crs
    return crs

def get_profile(path: Path) -> dict:
    with rasterio.open(path) as ds:
        p = ds.profile
    return p


def read_one(path: Path) -> tuple:
    with rasterio.open(path) as ds:
        p = ds.profile
        X = ds.read()
    return X, p

def merge_one_dir(acq_dir: Path, layer='gen-status') -> list:
    reg_dict = {'gen-status': 'GEN-DIST-STATUS.tif',
                'gen-date': 'GEN-DIST-DATE.tif',
                'veg-status': 'VEG-DIST-STATUS.tif',
                'veg-date': 'VEG-DIST-DATE.tif'}

    if layer not in reg_dict.keys():
        raise ValueError('layer not correctly specified')
    all_img_paths = sorted(list(acq_dir.glob(f'OPERA*{reg_dict[layer]}')))
    crs_l = list(map(get_crs, all_img_paths))
    
    
    stem = acq_dir.stem
    dst_path = acq_dir / f'__{stem}_{layer}_merged.tif'
    if len(list(set(crs_l))) == 1:
        merge(all_img_paths, method='first', dst_path=dst_path)
    else:
        profiles = list(map(get_profile, all_img_paths))
        ref_crs = crs_l[0]
        ref_profile = profiles[0]

        with rasterio.open(all_img_paths[0]) as ds:
            cmap = ds.colormap(1)
        zipped_data = [read_one(path) for path in all_img_paths]
        zipped_data = [(X, p) if p['crs'] == ref_crs 
                       else reproject_arr_to_new_crs(X, 
                                                     p, 
                                                     ref_crs, 
                                                     resampling='nearest') 
                       for (X, p) in zipped_data ]
        arrays, profiles_dst = zip(*zipped_data)
        arrays = [arr[0, ...] for arr in arrays]
        X_m, p_m = merge_arrays_with_geometadata(arrays, 
                                                 profiles_dst, 
                                                 resampling='nearest',
                                                 method='first')
        with rasterio.open(dst_path, 'w', **p_m) as ds:
            ds.write(X_m)
            ds.write_colormap(1, cmap)
    return dst_path

# %%
list(enumerate(all_acq_dirs))
# Out:
# [(0, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-10__L9')),
#  (1, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B')),
#  (2, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A')),
#  (3, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__L8')),
#  (4, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B')),
#  (5, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A')),
#  (6, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__L9')),
#  (7, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A')),
#  (8, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B')),
#  (9, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-31__S2B')),
#  (10, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A')),
#  (11, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-03__L8')),
#  (12, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A')),
#  (13, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B')),
#  (14, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B')),
#  (15, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-11__L9')),
#  (16, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A')),
#  (17, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A')),
#  (18, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B')),
#  (19, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-19__L8')),
#  (20, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B')),
#  (21, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A')),
#  (22, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A')),
#  (23, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__L9')),
#  (24, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B')),
#  (25, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B')),
#  (26, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A')),
#  (27, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__L8')),
#  (28, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A')),
#  (29, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B')),
#  (30, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B')),
#  (31, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A')),
#  (32, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-13__L9')),
#  (33, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A')),
#  (34, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B')),
#  (35, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B')),
#  (36, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A')),
#  (37, PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-25__S2A'))]

# %%
merge_one_dir(all_acq_dirs[0], layer='veg-status')
# Out:
# PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/__2024-05-10__L9_veg-status_merged.tif')

# %%
dst_paths_veg_status = [merge_one_dir(acq_dir, layer='veg-status') for acq_dir in tqdm(all_acq_dirs)]
dst_paths_veg_date = [merge_one_dir(acq_dir, layer='veg-date') for acq_dir in tqdm(all_acq_dirs)]

dst_paths_gen_status = [merge_one_dir(acq_dir, layer='gen-status') for acq_dir in tqdm(all_acq_dirs)]
dst_paths_gen_date = [merge_one_dir(acq_dir, layer='gen-date') for acq_dir in tqdm(all_acq_dirs)]

dst_paths_veg_status, dst_paths_gen_status
# Out:
# 100%|██████████████████████████████████████████| 38/38 [00:04<00:00,  8.90it/s]
# 100%|██████████████████████████████████████████| 38/38 [00:05<00:00,  6.35it/s]
# 100%|██████████████████████████████████████████| 38/38 [00:03<00:00, 12.41it/s]
# 100%|██████████████████████████████████████████| 38/38 [00:04<00:00,  8.26it/s]
# ([PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/__2024-05-10__L9_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/__2024-05-11__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/__2024-05-13__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/__2024-05-18__L8_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/__2024-05-18__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/__2024-05-23__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/__2024-05-26__L9_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/__2024-05-26__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/__2024-05-28__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-31__S2B/__2024-05-31__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/__2024-06-02__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/__2024-06-03__L8_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/__2024-06-05__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B/__2024-06-07__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/__2024-06-10__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/__2024-06-11__L9_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/__2024-06-12__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/__2024-06-15__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/__2024-06-17__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/__2024-06-19__L8_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/__2024-06-20__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/__2024-06-22__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/__2024-06-25__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/__2024-06-27__L9_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/__2024-06-27__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/__2024-06-30__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/__2024-07-02__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/__2024-07-05__L8_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/__2024-07-05__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/__2024-07-07__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/__2024-07-10__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/__2024-07-12__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/__2024-07-13__L9_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/__2024-07-15__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/__2024-07-17__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/__2024-07-20__S2B_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/__2024-07-22__S2A_veg-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-25__S2A/__2024-07-25__S2A_veg-status_merged.tif')],
#  [PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-10__L9/__2024-05-10__L9_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-11__S2B/__2024-05-11__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-13__S2A/__2024-05-13__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__L8/__2024-05-18__L8_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-18__S2B/__2024-05-18__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-23__S2A/__2024-05-23__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__L9/__2024-05-26__L9_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-26__S2A/__2024-05-26__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-28__S2B/__2024-05-28__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-05-31__S2B/__2024-05-31__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-02__S2A/__2024-06-02__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-03__L8/__2024-06-03__L8_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-05__S2A/__2024-06-05__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-07__S2B/__2024-06-07__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-10__S2B/__2024-06-10__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-11__L9/__2024-06-11__L9_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-12__S2A/__2024-06-12__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-15__S2A/__2024-06-15__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-17__S2B/__2024-06-17__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-19__L8/__2024-06-19__L8_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-20__S2B/__2024-06-20__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-22__S2A/__2024-06-22__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-25__S2A/__2024-06-25__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__L9/__2024-06-27__L9_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-27__S2B/__2024-06-27__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-06-30__S2B/__2024-06-30__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-02__S2A/__2024-07-02__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__L8/__2024-07-05__L8_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-05__S2A/__2024-07-05__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-07__S2B/__2024-07-07__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-10__S2B/__2024-07-10__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-12__S2A/__2024-07-12__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-13__L9/__2024-07-13__L9_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-15__S2A/__2024-07-15__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-17__S2B/__2024-07-17__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-20__S2B/__2024-07-20__S2B_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-22__S2A/__2024-07-22__S2A_gen-status_merged.tif'),
#   PosixPath('out/papau_new_guinea_2024/dist_hls/2024-07-25__S2A/__2024-07-25__S2A_gen-status_merged.tif')])

# %%
ts_dir = dist_hls.parent / 'dist_hls_ts_merged'
ts_dir.mkdir(exist_ok=True, parents=True)
ts_dir
# Out:
# PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged')

# %%
def get_idx_with_largest_size(paths: list[Path]) -> int:
    def get_size(path: Path) -> int:
        with rasterio.open(path) as ds:
            m, n = ds.shape

        return m * n

    sizes = list(map(get_size, paths))
    idx = np.argmax(sizes)
    return idx

def make_cube(paths: list[Path]):
    ref_idx = get_idx_with_largest_size(paths)


    profiles = list(map(get_profile, paths))
    ref_profile = profiles[ref_idx]

    cube_paths = []
    for p, path in zip(tqdm(profiles), paths):
        out_path = ts_dir / path.name
        
        cond0 = (p['transform'] == ref_profile['transform'])
        cond1 = (p['width'] == ref_profile['width'])
        cond2 = (p['height'] == ref_profile['height'])
        cond3 = (p['crs'] == ref_profile['crs'])
        if cond0 and cond1 and cond2 and cond3:
            shutil.copyfile(path, out_path)
        else:
            with rasterio.open(path) as ds:
                X = ds.read(1)
                p = ds.profile
                if 'status' in path.stem.lower():
                    cmap = ds.colormap(1)
            X_r, p_r = reproject_arr_to_match_profile(X, p, ref_profile)
            with rasterio.open(out_path, 'w', **p_r) as ds:
                ds.write(X_r)
                if 'status' in path.stem.lower():
                    ds.write_colormap(1, cmap)
        cube_paths.append(out_path)
    
    return cube_paths

# %%
merged_veg_status = make_cube(dst_paths_veg_status)
merged_gen_status = make_cube(dst_paths_gen_status)

merged_veg_date = make_cube(dst_paths_veg_date)
merged_gen_date = make_cube(dst_paths_gen_date)
# Out:
# 100%|████████████████████████████████████████| 38/38 [00:00<00:00, 1469.50it/s]
# 100%|████████████████████████████████████████| 38/38 [00:00<00:00, 1212.59it/s]
# 100%|█████████████████████████████████████████| 38/38 [00:00<00:00, 570.57it/s]
# 100%|█████████████████████████████████████████| 38/38 [00:00<00:00, 689.91it/s]

# %%
list(enumerate(merged_veg_status))
# Out:
# [(0,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-10__L9_veg-status_merged.tif')),
#  (1,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-11__S2B_veg-status_merged.tif')),
#  (2,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-13__S2A_veg-status_merged.tif')),
#  (3,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-18__L8_veg-status_merged.tif')),
#  (4,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-18__S2B_veg-status_merged.tif')),
#  (5,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-23__S2A_veg-status_merged.tif')),
#  (6,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-26__L9_veg-status_merged.tif')),
#  (7,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-26__S2A_veg-status_merged.tif')),
#  (8,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-28__S2B_veg-status_merged.tif')),
#  (9,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-05-31__S2B_veg-status_merged.tif')),
#  (10,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-02__S2A_veg-status_merged.tif')),
#  (11,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-03__L8_veg-status_merged.tif')),
#  (12,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-05__S2A_veg-status_merged.tif')),
#  (13,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-07__S2B_veg-status_merged.tif')),
#  (14,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-10__S2B_veg-status_merged.tif')),
#  (15,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-11__L9_veg-status_merged.tif')),
#  (16,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-12__S2A_veg-status_merged.tif')),
#  (17,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-15__S2A_veg-status_merged.tif')),
#  (18,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-17__S2B_veg-status_merged.tif')),
#  (19,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-19__L8_veg-status_merged.tif')),
#  (20,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-20__S2B_veg-status_merged.tif')),
#  (21,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-22__S2A_veg-status_merged.tif')),
#  (22,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-25__S2A_veg-status_merged.tif')),
#  (23,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-27__L9_veg-status_merged.tif')),
#  (24,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-27__S2B_veg-status_merged.tif')),
#  (25,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-06-30__S2B_veg-status_merged.tif')),
#  (26,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-02__S2A_veg-status_merged.tif')),
#  (27,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-05__L8_veg-status_merged.tif')),
#  (28,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-05__S2A_veg-status_merged.tif')),
#  (29,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-07__S2B_veg-status_merged.tif')),
#  (30,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-10__S2B_veg-status_merged.tif')),
#  (31,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-12__S2A_veg-status_merged.tif')),
#  (32,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-13__L9_veg-status_merged.tif')),
#  (33,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-15__S2A_veg-status_merged.tif')),
#  (34,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-17__S2B_veg-status_merged.tif')),
#  (35,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-20__S2B_veg-status_merged.tif')),
#  (36,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-22__S2A_veg-status_merged.tif')),
#  (37,
#   PosixPath('out/papau_new_guinea_2024/dist_hls_ts_merged/__2024-07-25__S2A_veg-status_merged.tif'))]

# %% [markdown]
# # Make Change Map

# %%
change_dir = dist_hls = Path('out') / event_dict['event_name'] / 'change_map_dist_hls'
change_dir.mkdir(exist_ok=True, parents=True)

# %%
from dateparser import parse
acq_dt_hls = [parse(p.stem.split('__')[1]) for p in dst_paths_veg_status]
acq_dt_hls
# Out:
# [datetime.datetime(2024, 5, 10, 0, 0),
#  datetime.datetime(2024, 5, 11, 0, 0),
#  datetime.datetime(2024, 5, 13, 0, 0),
#  datetime.datetime(2024, 5, 18, 0, 0),
#  datetime.datetime(2024, 5, 18, 0, 0),
#  datetime.datetime(2024, 5, 23, 0, 0),
#  datetime.datetime(2024, 5, 26, 0, 0),
#  datetime.datetime(2024, 5, 26, 0, 0),
#  datetime.datetime(2024, 5, 28, 0, 0),
#  datetime.datetime(2024, 5, 31, 0, 0),
#  datetime.datetime(2024, 6, 2, 0, 0),
#  datetime.datetime(2024, 6, 3, 0, 0),
#  datetime.datetime(2024, 6, 5, 0, 0),
#  datetime.datetime(2024, 6, 7, 0, 0),
#  datetime.datetime(2024, 6, 10, 0, 0),
#  datetime.datetime(2024, 6, 11, 0, 0),
#  datetime.datetime(2024, 6, 12, 0, 0),
#  datetime.datetime(2024, 6, 15, 0, 0),
#  datetime.datetime(2024, 6, 17, 0, 0),
#  datetime.datetime(2024, 6, 19, 0, 0),
#  datetime.datetime(2024, 6, 20, 0, 0),
#  datetime.datetime(2024, 6, 22, 0, 0),
#  datetime.datetime(2024, 6, 25, 0, 0),
#  datetime.datetime(2024, 6, 27, 0, 0),
#  datetime.datetime(2024, 6, 27, 0, 0),
#  datetime.datetime(2024, 6, 30, 0, 0),
#  datetime.datetime(2024, 7, 2, 0, 0),
#  datetime.datetime(2024, 7, 5, 0, 0),
#  datetime.datetime(2024, 7, 5, 0, 0),
#  datetime.datetime(2024, 7, 7, 0, 0),
#  datetime.datetime(2024, 7, 10, 0, 0),
#  datetime.datetime(2024, 7, 12, 0, 0),
#  datetime.datetime(2024, 7, 13, 0, 0),
#  datetime.datetime(2024, 7, 15, 0, 0),
#  datetime.datetime(2024, 7, 17, 0, 0),
#  datetime.datetime(2024, 7, 20, 0, 0),
#  datetime.datetime(2024, 7, 22, 0, 0),
#  datetime.datetime(2024, 7, 25, 0, 0)]

# %% [markdown]
# ## Change Maps from Provisional Alert

# %%
N_ACQS = 3

# %%
PROVISIONAL_CHANGE_MAP_IDXS = [k for (k, dt) in enumerate(acq_dt_hls) if dt > EVENT_DT][:3]
PROVISIONAL_CHANGE_MAP_IDXS, [acq_dt_hls[k] for k in PROVISIONAL_CHANGE_MAP_IDXS]
# Out:
# ([6, 7, 8],
#  [datetime.datetime(2024, 5, 26, 0, 0),
#   datetime.datetime(2024, 5, 26, 0, 0),
#   datetime.datetime(2024, 5, 28, 0, 0)])

# %%
for data_list, change_token in zip([merged_veg_status, merged_gen_status], ['veg', 'gen']):
    profiles = []
    change_arrays = []
    for idx in PROVISIONAL_CHANGE_MAP_IDXS:
        with rasterio.open(data_list[idx]) as ds:
            X_status_prov = ds.read(1)
            p = ds.profile
        
        X_change_prov = np.zeros(X_status_prov.shape)
    
        confirmed_change_labels = [3, 6, 7, 8]
        X_change_prov[np.isin(X_status_prov, confirmed_change_labels)] = 255
    
        prov_change_labels = [1, 2, 3, 5]
        X_change_prov[np.isin(X_status_prov, prov_change_labels)] = 1
    
        #no_change_labels = [0]
        #X_change_prov[np.isin(X_status_prov, no_change_labels)] = 0
    
        X_change_prov[X_status_prov == 255] = 255
        
        profiles.append(p)
        change_arrays.append(X_change_prov)

    X_change_prov_m, p_m = merge_arrays_with_geometadata(change_arrays, profiles, method='max')

    out_path = change_dir / f'dist_hls_provisional_change_map_{change_token}_first{str(acq_dt_hls[PROVISIONAL_CHANGE_MAP_IDXS[0]].date())}.tif'
    print(out_path)
    with rasterio.open(out_path, 'w', **p_m) as ds:
        ds.write(X_change_prov_m.astype(np.uint8))
# Out:
# out/papau_new_guinea_2024/change_map_dist_hls/dist_hls_provisional_change_map_veg_first2024-05-26.tif
# out/papau_new_guinea_2024/change_map_dist_hls/dist_hls_provisional_change_map_gen_first2024-05-26.tif

# %%
X_change_prov_p = X_change_prov.copy()
X_change_prov_p[X_change_prov_p == 255] = np.nan
plt.imshow(X_change_prov_p, vmin=0, vmax=1, interpolation='none')

# %% [markdown]
# ## Confirmed Change Map

# %%
min_days = event_dict['dist_hls_confirmed_change_min_days']
CHANGE_MAP_CONFIRMED_IDXS = [k for (k, dt) in enumerate(acq_dt_hls) if dt > EVENT_DT + datetime.timedelta(min_days)][:N_ACQS]
CHANGE_MAP_CONFIRMED_IDXS, [acq_dt_hls[k] for k in PROVISIONAL_CHANGE_MAP_IDXS]
# Out:
# ([14, 15, 16],
#  [datetime.datetime(2024, 5, 26, 0, 0),
#   datetime.datetime(2024, 5, 26, 0, 0),
#   datetime.datetime(2024, 5, 28, 0, 0)])

# %%
for data_list_status, data_list_date, change_token in zip([merged_veg_status, merged_gen_status], 
                                          [merged_veg_date, merged_gen_date],
                                          ['veg', 'gen']):
    profiles = []
    change_arrays = []
    for idx in CHANGE_MAP_CONFIRMED_IDXS:
    
        with rasterio.open(data_list_status[idx]) as ds:
            X_status_con = ds.read(1)
            p = ds.profile
    
        with rasterio.open(data_list_date[idx]) as ds:
            X_date = ds.read(1)
    
        confirmed_event_day_val = (EVENT_DT - datetime.datetime(2020, 12, 31)).days
        X_change_con = np.zeros(X_status_con.shape)
        
        confirmed_change_labels = [3, 6, 7, 8]
        # I am adding a 1 day buffer to the confirmed day boolean index
        X_change_con[np.isin(X_status_con, confirmed_change_labels) & (X_date >= confirmed_event_day_val - 1)] = 1
    
        #prov_change_labels = [1, 2, 3, 5]
        #X_change_con[np.isin(X_status_con, prov_change_labels)] = 255
        
        X_change_con[X_status_con == 255] = 255

        profiles.append(p)
        change_arrays.append(X_change_con)

    X_change_con_m, p_m = merge_arrays_with_geometadata(change_arrays, profiles, method='max')


    out_path = change_dir / f'dist_hls_confirmed_change_map_{change_token}_first{str(acq_dt_hls[CHANGE_MAP_CONFIRMED_IDX].date())}.tif'
    print(out_path)
    with rasterio.open(out_path, 'w', **p) as ds:
        ds.write(X_change_con_m.astype(np.uint8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 33
#      28     change_arrays.append(X_change_con)
#      30 X_change_con_m, p_m = merge_arrays_with_geometadata(change_arrays, profiles, method='max')
# ---> 33 out_path = change_dir / f'dist_hls_confirmed_change_map_{change_token}_first{str(acq_dt_hls[CHANGE_MAP_CONFIRMED_IDX].date())}.tif'
#      34 print(out_path)
#      35 with rasterio.open(out_path, 'w', **p) as ds:
#
# NameError: name 'CHANGE_MAP_CONFIRMED_IDX' is not defined

# %%
plt.imshow(X_change_con_m[0, ...], vmin=0, vmax=1, interpolation='none')
