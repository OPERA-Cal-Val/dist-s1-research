# %%
import geopandas as gpd
import pandas as pd

# %%
#df_event = gpd.read_file('external_validation_data/WFIGS_interagency_fire_db/park_2024.geojson').cx[:-120, :]
df_event = gpd.read_file('external_validation_data/WFIGS_interagency_fire_db/smokehouse_creek_2024.geojson')

df_event.head()
# Out:
#    index              name               create_time  \
# 0   1032  Smokehouse Creek 2024-03-19 20:06:11+00:00
#
#    attr_ContainmentDateTime                                           geometry
# 0 2024-03-17 02:35:26+00:00  MULTIPOLYGON (((-101.00350 35.61311, -101.0035...

# %%
df_event.plot()
# Out:
# <Axes: >

# %%
df_event.total_bounds
# Out:
# array([-101.54123593,   35.53176534,  -99.89106839,   36.05943529])
