# %%
import geopandas as gpd
import rasterio
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
from rasterio.warp import transform_bounds
from tile_mate import get_raster_from_tiles
from rasterio.crs import CRS
from dem_stitcher.rio_tools import reproject_arr_to_match_profile
import numpy as np
from rasterio.transform import xy
from shapely.geometry import Point
from rasterio.plot import show
from dswx_sar.filter_SAR import lee_enhanced_filter

# %%
BURST_ID = 'T018_038457_IW2'.upper().replace('-', '_')

# %%
ts_dir = Path('burst_time_series')
burst_dir = ts_dir / BURST_ID
assert burst_dir.exists()

# %%
metadata_geojson = burst_dir / f'metadata_{BURST_ID}_rtc_ts.geojson'

# %%
df_meta = gpd.read_file(metadata_geojson)
df_meta.head()
# Out:
#                                             opera_id  \
# 0  OPERA_L2_RTC-S1_T018-038457-IW2_20231007T23284...
# 1  OPERA_L2_RTC-S1_T018-038457-IW2_20231019T23284...
# 2  OPERA_L2_RTC-S1_T018-038457-IW2_20231031T23284...
# 3  OPERA_L2_RTC-S1_T018-038457-IW2_20231112T23284...
# 4  OPERA_L2_RTC-S1_T018-038457-IW2_20231124T23284...
#
#                  start_time  \
# 0 2023-10-07 23:28:48+00:00
# 1 2023-10-19 23:28:48+00:00
# 2 2023-10-31 23:28:48+00:00
# 3 2023-11-12 23:28:48+00:00
# 4 2023-11-24 23:28:47+00:00
#
#                                               url_vh  \
# 0  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 1  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 2  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 3  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 4  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
#
#                                               url_vv  track_number  \
# 0  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 1  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 2  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 3  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 4  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
#
#                                        local_path_vv  \
# 0  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                        local_path_vh  \
# 0  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                     local_path_vh_tv  \
# 0  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                     local_path_vv_tv  \
# 0  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                             geometry
# 0  POLYGON ((-71.56223 -33.27870, -71.50894 -33.2...
# 1  POLYGON ((-71.56304 -33.27879, -71.50975 -33.2...
# 2  POLYGON ((-71.56189 -33.27894, -71.09011 -33.1...
# 3  POLYGON ((-71.56319 -33.27800, -71.09140 -33.1...
# 4  POLYGON ((-71.56064 -33.27817, -71.08885 -33.1...

# %% [markdown]
# Sanity check

# %%
def get_trans_and_shape(path: str) -> tuple:
    with rasterio.open(path) as ds:
        t = ds.transform
        s = ds.shape
    return t, s

data = [get_trans_and_shape(path) for path in df_meta.local_path_vh.tolist()]
unique_date = list(set(data))
unique_date
# Out:
# [(Affine(30.0, 0.0, 250470.0,
#          0.0, -30.0, 6368190.0),
#   (1907, 3440))]

# %%
with rasterio.open(df_meta.local_path_vh.tolist()[0]) as ds:
    p_rtc = ds.profile
    bounds = ds.bounds
bounds, p_rtc
# Out:
# (BoundingBox(left=250470.0, bottom=6310980.0, right=353670.0, top=6368190.0),
#  {'driver': 'GTiff', 'dtype': 'float32', 'nodata': nan, 'width': 3440, 'height': 1907, 'count': 1, 'crs': CRS.from_epsg(32719), 'transform': Affine(30.0, 0.0, 250470.0,
#         0.0, -30.0, 6368190.0), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'})

# %%
bounds_4326 = transform_bounds(p_rtc['crs'], CRS.from_epsg(4326), *bounds)
bounds_4326
# Out:
# (-71.68024090353879,
#  -33.33040515977752,
#  -70.56309413811026,
#  -32.795944748936236)

# %% [markdown]
# # Generate Pekel Water Mask

# %%
X_occ, p_occ = get_raster_from_tiles(bounds_4326, tile_shortname='pekel_water_occ_2021')
# Out:
# Reading tile metadata: 100%|█| 1/1 [00:00<00:00, 376
# Reading tile imagery: 100%|█| 1/1 [00:04<00:00,  4.9

# %%
X_occ = X_occ.astype(np.float32)
p_occ['dtype'] = 'float32'
X_occ_r, _ = reproject_arr_to_match_profile(X_occ, p_occ, p_rtc, resampling='bilinear')

# %%
WATER_MASK = (X_occ_r > 95)[0, ...]

# %%
p_wtr = p_occ.copy()
p_wtr['dtype'] = np.uint
with rasterio.open(ts_dir / 'water_mask.tif', 'w', **p_wtr) as ds:
    ds.write(WATER_MASK.astype('uint8'), 1)

# %% [markdown]
# # Load Time Series

# %%
def open_one(path: str) -> tuple:
    with rasterio.open(path) as ds:
        X = ds.read(1)
        p = ds.profile
    X[WATER_MASK] = np.nan
    ## Clip
    if '_VV.tif' == path[-7:]:
        X = np.clip(X, 1e-7, 1)
    else:
        X = np.clip(X, 1e-7, .5)
    return X, p

# %%
arrs_vv, profiles = zip(*[open_one(p) for p in tqdm(df_meta.local_path_vv)])
arrs_vh, _ = zip(*[open_one(p) for p in tqdm(df_meta.local_path_vh)])
# Out:
# 100%|███████████████| 15/15 [00:01<00:00, 10.17it/s]
# 100%|███████████████| 15/15 [00:01<00:00, 10.44it/s]

# %%
acq_dt = df_meta.start_time.tolist()
acq_dt[:2]
# Out:
# [Timestamp('2023-10-07 23:28:48+0000', tz='UTC'),
#  Timestamp('2023-10-19 23:28:48+0000', tz='UTC')]

# %%
plt.imshow(arrs_vv[0], vmax=.5)
plt.colorbar()

# %%
plt.imshow(arrs_vh[0], vmax=.15)
plt.colorbar()

# %%
X_vh_samp = arrs_vh[0]
X_vv_samp = arrs_vv[0]

RTC_MASK = np.isnan(X_vh_samp)

# %% [markdown]
# # Zoom in
#
# Randomly sampled window

# %%
np.random.seed(0)
rows, cols = np.where(~RTC_MASK)
window_size = 200
N = 4  # sample number 143

K = np.random.randint(len(rows), size=len(rows))[N]

sy = np.s_[rows[K] - window_size //2: rows[K] + window_size // 2]
sx = np.s_[cols[K] - window_size //2: cols[K] + window_size // 2]

# %%
Z = X_vv_samp[sy, sx]

# %%
plt.imshow(Z, vmax=.5)

# %%
from skimage.restoration import denoise_tv_bregman

# %%
def despeckle_one(X: np.ndarray, lamb=8) -> np.ndarray:
    X_db = np.log10(X, out=np.full(X.shape, np.nan), where=(~np.isnan(X)))
    X_db[np.isnan(X)] = 0.
    X_db_dspkl = denoise_tv_bregman(X_db, weight=lamb)
    X_dspkl = np.power(10, X_db_dspkl)
    X_dspkl[np.isnan(X)] = np.nan
    return X_dspkl

# %%
ZZ = despeckle_one(Z)
ZZ_lee = lee_enhanced_filter(Z)
# Out:
# >> lee_enhanced_filter

# %%
plt.imshow(ZZ, vmax=.5, vmin=0)

# %%
plt.imshow(ZZ_lee, vmax=.5, vmin=0)

# %%
X_vh_samp_dspkl = despeckle_one(X_vh_samp)

# %%
X_vh_samp_lee = lee_enhanced_filter(X_vh_samp)
# Out:
# >> lee_enhanced_filter

# %%
plt.imshow(X_vh_samp)

# %%
plt.imshow(X_vh_samp_dspkl)

# %%
plt.imshow(X_vh_samp_lee)

# %% [markdown]
# # Despeckle all

# %%
arrs_vv_tv = list(map(despeckle_one, tqdm(arrs_vv)))
# Out:
# 100%|███████████████| 15/15 [00:19<00:00,  1.27s/it]

# %%
arrs_vh_tv = list(map(despeckle_one, tqdm(arrs_vh)))
# Out:
# 100%|███████████████| 15/15 [00:20<00:00,  1.35s/it]

# %%
arrs_vv_lee = list(map(lee_enhanced_filter, tqdm(arrs_vv)))
# Out:
#   0%|                        | 0/15 [00:00<?, ?it/s]
# >> lee_enhanced_filter
#   7%|█               | 1/15 [00:00<00:07,  1.93it/s]
# >> lee_enhanced_filter
#  13%|██▏             | 2/15 [00:01<00:06,  1.92it/s]
# >> lee_enhanced_filter
#  20%|███▏            | 3/15 [00:01<00:06,  1.89it/s]
# >> lee_enhanced_filter
#  27%|████▎           | 4/15 [00:02<00:05,  1.89it/s]
# >> lee_enhanced_filter
#  33%|█████▎          | 5/15 [00:02<00:05,  1.90it/s]
# >> lee_enhanced_filter
#  40%|██████▍         | 6/15 [00:03<00:04,  1.87it/s]
# >> lee_enhanced_filter
#  47%|███████▍        | 7/15 [00:03<00:04,  1.87it/s]
# >> lee_enhanced_filter
#  53%|████████▌       | 8/15 [00:04<00:03,  1.87it/s]
# >> lee_enhanced_filter
#  60%|█████████▌      | 9/15 [00:04<00:03,  1.87it/s]
# >> lee_enhanced_filter
#  67%|██████████     | 10/15 [00:05<00:02,  1.87it/s]
# >> lee_enhanced_filter
#  73%|███████████    | 11/15 [00:05<00:02,  1.88it/s]
# >> lee_enhanced_filter
#  80%|████████████   | 12/15 [00:06<00:01,  1.87it/s]
# >> lee_enhanced_filter
#  87%|█████████████  | 13/15 [00:06<00:01,  1.88it/s]
# >> lee_enhanced_filter
#  93%|██████████████ | 14/15 [00:07<00:00,  1.87it/s]
# >> lee_enhanced_filter
# 100%|███████████████| 15/15 [00:07<00:00,  1.88it/s]

# %%
arrs_vh_lee = list(map(lee_enhanced_filter, tqdm(arrs_vh)))
# Out:
#   0%|                        | 0/15 [00:00<?, ?it/s]
# >> lee_enhanced_filter
#   7%|█               | 1/15 [00:00<00:07,  1.92it/s]
# >> lee_enhanced_filter
#  13%|██▏             | 2/15 [00:01<00:06,  1.90it/s]
# >> lee_enhanced_filter
#  20%|███▏            | 3/15 [00:01<00:06,  1.91it/s]
# >> lee_enhanced_filter
#  27%|████▎           | 4/15 [00:02<00:05,  1.90it/s]
# >> lee_enhanced_filter
#  33%|█████▎          | 5/15 [00:02<00:05,  1.91it/s]
# >> lee_enhanced_filter
#  40%|██████▍         | 6/15 [00:03<00:04,  1.91it/s]
# >> lee_enhanced_filter
#  47%|███████▍        | 7/15 [00:03<00:04,  1.90it/s]
# >> lee_enhanced_filter
#  53%|████████▌       | 8/15 [00:04<00:03,  1.89it/s]
# >> lee_enhanced_filter
#  60%|█████████▌      | 9/15 [00:04<00:03,  1.88it/s]
# >> lee_enhanced_filter
#  67%|██████████     | 10/15 [00:05<00:02,  1.88it/s]
# >> lee_enhanced_filter
#  73%|███████████    | 11/15 [00:05<00:02,  1.87it/s]
# >> lee_enhanced_filter
#  80%|████████████   | 12/15 [00:06<00:01,  1.88it/s]
# >> lee_enhanced_filter
#  87%|█████████████  | 13/15 [00:06<00:01,  1.89it/s]
# >> lee_enhanced_filter
#  93%|██████████████ | 14/15 [00:07<00:00,  1.89it/s]
# >> lee_enhanced_filter
# 100%|███████████████| 15/15 [00:07<00:00,  1.89it/s]

# %% [markdown]
# # Serialize

# %%
paths_vv = list(map(Path, df_meta.local_path_vv))
paths_vh = list(map(Path, df_meta.local_path_vh))
paths_vh[0].name, paths_vh[0].parent.name
# Out:
# ('OPERA_L2_RTC-S1_T018-038457-IW2_20231007T232848Z_20231008T182355Z_S1A_30_v1.0_VH.tif',
#  'OPERA_L2_RTC-S1_T018-038457-IW2_20231007T232848Z_20231008T182355Z_S1A_30_v1.0')

# %%
# #import colormap
# import matplotlib
# from matplotlib import cm

# #normalize item number values to colormap
# norm = matplotlib.colors.Normalize(vmin=0, vmax=.5)

# #colormap possible values = viridis, jet, spectral
# rgba_color = cm.viridis(.15, bytes=True, alpha=1) 
# rgba_color
# Out:
# (69, 52, 127, 255)

# %%
# X_int = ((X - .5) / (.5)) * 255
# X_int = rgba.astype(np.uint8)
# X_int[np.isnan(X)] = 255

# %%
# plt.imshow(X_int)

# %%
# rgba = skimage.color.gray2rgba(X, alpha=1, channel_axis=-1) * 255
# rgba = rgba.astype(np.uint8)

# %%
def serialize_one(arr: np.ndarray, src_path: Path) -> str:
    fn = src_path.name
    opera_id = src_path.parent.name

    burst_dir = src_path.parent
    #dst_fn = fn.replace('.tif', '_tv_cmap.tif')
    dst_fn = fn.replace('.tif', '_tv.tif')

    out_path = burst_dir / dst_fn

    # arr_int = ((arr - .5) / (.5)) * 255
    # arr_int = arr_int.astype(np.uint8)
    # arr_int[np.isnan(arr)] = 255
    
    # norm = matplotlib.colors.Normalize(vmin=0, vmax=255)
    # keys = sorted(np.unique(X_int))
    # print(keys)
    # colors = cm.viridis(norm(keys), bytes=True, alpha=1)
    # cmap = {k: tuple(c) for (k, c) in zip(keys, colors)}
    # #cmap[255] = (0, 0, 0, 0)
    # print(cmap)
    p_int = p_rtc.copy()
    # p_int['dtype'] = np.uint8
    # p_int['nodata'] = 255
    with rasterio.open(out_path, 'w', **p_int) as ds:
        ds.write(arr, 1)
        #ds.write_colormap(1, cmap)
    return out_path

# %%
vv_tv_paths = [serialize_one(arr, src_path) for (arr, src_path) in zip(tqdm(arrs_vv_tv), paths_vv[:])]
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  8.85it/s]

# %%
vh_tv_paths = [serialize_one(arr, src_path) for (arr, src_path) in zip(tqdm(arrs_vh_tv), paths_vh)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  8.78it/s]

# %%
df_meta
# Out:
#                                              opera_id  \
# 0   OPERA_L2_RTC-S1_T018-038457-IW2_20231007T23284...
# 1   OPERA_L2_RTC-S1_T018-038457-IW2_20231019T23284...
# 2   OPERA_L2_RTC-S1_T018-038457-IW2_20231031T23284...
# 3   OPERA_L2_RTC-S1_T018-038457-IW2_20231112T23284...
# 4   OPERA_L2_RTC-S1_T018-038457-IW2_20231124T23284...
# 5   OPERA_L2_RTC-S1_T018-038457-IW2_20231206T23284...
# 6   OPERA_L2_RTC-S1_T018-038457-IW2_20231218T23284...
# 7   OPERA_L2_RTC-S1_T018-038457-IW2_20231230T23284...
# 8   OPERA_L2_RTC-S1_T018-038457-IW2_20240111T23284...
# 9   OPERA_L2_RTC-S1_T018-038457-IW2_20240123T23284...
# 10  OPERA_L2_RTC-S1_T018-038457-IW2_20240204T23284...
# 11  OPERA_L2_RTC-S1_T018-038457-IW2_20240216T23284...
# 12  OPERA_L2_RTC-S1_T018-038457-IW2_20240228T23284...
# 13  OPERA_L2_RTC-S1_T018-038457-IW2_20240228T23284...
# 14  OPERA_L2_RTC-S1_T018-038457-IW2_20240311T23284...
#
#                   start_time  \
# 0  2023-10-07 23:28:48+00:00
# 1  2023-10-19 23:28:48+00:00
# 2  2023-10-31 23:28:48+00:00
# 3  2023-11-12 23:28:48+00:00
# 4  2023-11-24 23:28:47+00:00
# 5  2023-12-06 23:28:47+00:00
# 6  2023-12-18 23:28:46+00:00
# 7  2023-12-30 23:28:46+00:00
# 8  2024-01-11 23:28:45+00:00
# 9  2024-01-23 23:28:44+00:00
# 10 2024-02-04 23:28:44+00:00
# 11 2024-02-16 23:28:44+00:00
# 12 2024-02-28 23:28:44+00:00
# 13 2024-02-28 23:28:44+00:00
# 14 2024-03-11 23:28:44+00:00
#
#                                                url_vh  \
# 0   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 1   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 2   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 3   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 4   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 5   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 6   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 7   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 8   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 9   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 10  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 11  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 12  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 13  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
# 14  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...
#
#                                                url_vv  track_number  \
# 0   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 1   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 2   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 3   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 4   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 5   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 6   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 7   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 8   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 9   https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 10  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 11  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 12  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 13  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
# 14  https://datapool.asf.alaska.edu/RTC/OPERA-S1/O...            18
#
#                                         local_path_vv  \
# 0   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 5   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 6   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 7   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 8   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 9   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 10  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 11  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 12  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 13  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 14  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                         local_path_vh  \
# 0   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 5   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 6   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 7   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 8   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 9   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 10  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 11  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 12  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 13  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 14  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                      local_path_vh_tv  \
# 0   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 5   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 6   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 7   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 8   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 9   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 10  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 11  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 12  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 13  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 14  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                      local_path_vv_tv  \
# 0   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 1   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 2   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 3   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 4   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 5   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 6   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 7   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 8   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 9   burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 10  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 11  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 12  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 13  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
# 14  burst_time_series/T018_038457_IW2/OPERA_L2_RTC...
#
#                                              geometry
# 0   POLYGON ((-71.56223 -33.27870, -71.50894 -33.2...
# 1   POLYGON ((-71.56304 -33.27879, -71.50975 -33.2...
# 2   POLYGON ((-71.56189 -33.27894, -71.09011 -33.1...
# 3   POLYGON ((-71.56319 -33.27800, -71.09140 -33.1...
# 4   POLYGON ((-71.56064 -33.27817, -71.08885 -33.1...
# 5   POLYGON ((-71.56203 -33.27741, -71.09025 -33.1...
# 6   POLYGON ((-71.56162 -33.27754, -71.08988 -33.1...
# 7   POLYGON ((-71.56374 -33.27756, -71.09194 -33.1...
# 8   POLYGON ((-71.56290 -33.27789, -71.09112 -33.1...
# 9   POLYGON ((-71.56265 -33.27767, -71.09087 -33.1...
# 10  POLYGON ((-71.56247 -33.27801, -71.09066 -33.1...
# 11  POLYGON ((-71.56262 -33.27800, -71.09080 -33.1...
# 12  POLYGON ((-71.56316 -33.27905, -71.09130 -33.1...
# 13  POLYGON ((-71.56316 -33.27905, -71.09130 -33.1...
# 14  POLYGON ((-71.56333 -33.27961, -71.09146 -33.1...

# %%
df_meta['local_path_vh_tv'] = list(map(str, vh_tv_paths))
df_meta['local_path_vv_tv'] = list(map(str, vv_tv_paths))
df_meta.to_file(metadata_geojson)
