# %%
import pandas as pd
from pathlib import Path
from dotenv import load_dotenv
import os

# %%
load_dotenv()
dist_data = os.getenv('DIST_S1_DATA_DIR')
dist_data_dir = Path(dist_data)
dist_data_dir
# Out:
# PosixPath('/mnt/trappist-r0/cmarshak/dist-s1-validation/generate_dist_s1_table/confirmed_products')

# %%
df_all_sites_with_ts = pd.read_csv('reference_tables/referenceTimeSeriesInterpolated16_16_goodFirst.csv')
